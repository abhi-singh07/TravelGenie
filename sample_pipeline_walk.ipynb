# %%
import random
import itertools
import json

# --------------------------
# Generate Sample JSON Data
# --------------------------

cities = [f"City{i}" for i in range(1, 11)]

# 1. Attractions JSON
attractions_json = []
for city in cities:
    attractions = []
    for i in range(5):
        attractions.append({
            "name": f"{city} Attraction {i+1}",
            "rating": round(random.uniform(3.5, 5.0), 1),
            "price": random.randint(100, 500)
        })
    attractions_json.append({"city": city, "attractions": attractions})

# 2. Restaurants JSON
restaurants_json = []
for city in cities:
    for i in range(4):
        restaurants_json.append({
            "city": city,
            "restaurant_name": f"{city} Restaurant {i+1}",
            "rating": round(random.uniform(3.0, 5.0), 1),
            "price": random.randint(150, 600)
        })

# 3. Hotels JSON
hotels_json = []
for city in cities:
    hotels = []
    for i in range(3):
        hotels.append({
            "name": f"{city} Hotel {i+1}",
            "price_per_night": random.randint(1000, 3000)
        })
    hotels_json.append({"city": city, "hotels": hotels})

# 4. Flights JSON (2 per city pair)
flights_json = []
city_pairs = list(itertools.permutations(cities, 2))
for (from_city, to_city) in city_pairs:
    for i in range(2):
        flights_json.append({
            "flight_name": f"{from_city[:3]}-{to_city[:3]}-{i+1}",
            "flight_from": from_city,
            "flight_to": to_city,
            "price": random.randint(1500, 5000),
            "duration_hr": round(random.uniform(1.0, 4.0), 1)
        })

# Return everything for next steps
(
    attractions_json,
    restaurants_json,
    hotels_json,
    flights_json
)
# Out:
# ([{'city': 'City1',
#    'attractions': [{'name': 'City1 Attraction 1', 'rating': 3.5, 'price': 473},
#     {'name': 'City1 Attraction 2', 'rating': 4.9, 'price': 120},
#     {'name': 'City1 Attraction 3', 'rating': 4.9, 'price': 351},
#     {'name': 'City1 Attraction 4', 'rating': 4.2, 'price': 377},
#     {'name': 'City1 Attraction 5', 'rating': 3.8, 'price': 332}]},
#   {'city': 'City2',
#    'attractions': [{'name': 'City2 Attraction 1', 'rating': 4.8, 'price': 110},
#     {'name': 'City2 Attraction 2', 'rating': 4.5, 'price': 403},
#     {'name': 'City2 Attraction 3', 'rating': 4.7, 'price': 346},
#     {'name': 'City2 Attraction 4', 'rating': 3.7, 'price': 367},
#     {'name': 'City2 Attraction 5', 'rating': 4.4, 'price': 174}]},
#   {'city': 'City3',
#    'attractions': [{'name': 'City3 Attraction 1', 'rating': 4.8, 'price': 160},
#     {'name': 'City3 Attraction 2', 'rating': 4.8, 'price': 303},
#     {'name': 'City3 Attraction 3', 'rating': 4.9, 'price': 482},
#     {'name': 'City3 Attraction 4', 'rating': 5.0, 'price': 399},
#     {'name': 'City3 Attraction 5', 'rating': 4.8, 'price': 425}]},
#   {'city': 'City4',
#    'attractions': [{'name': 'City4 Attraction 1', 'rating': 4.6, 'price': 337},
#     {'name': 'City4 Attraction 2', 'rating': 3.7, 'price': 444},
#     {'name': 'City4 Attraction 3', 'rating': 4.5, 'price': 470},
#     {'name': 'City4 Attraction 4', 'rating': 4.6, 'price': 121},
#     {'name': 'City4 Attraction 5', 'rating': 5.0, 'price': 368}]},
#   {'city': 'City5',
#    'attractions': [{'name': 'City5 Attraction 1', 'rating': 4.5, 'price': 275},
#     {'name': 'City5 Attraction 2', 'rating': 3.8, 'price': 124},
#     {'name': 'City5 Attraction 3', 'rating': 4.5, 'price': 456},
#     {'name': 'City5 Attraction 4', 'rating': 3.9, 'price': 433},
#     {'name': 'City5 Attraction 5', 'rating': 4.5, 'price': 202}]},
#   {'city': 'City6',
#    'attractions': [{'name': 'City6 Attraction 1', 'rating': 3.8, 'price': 222},
#     {'name': 'City6 Attraction 2', 'rating': 3.6, 'price': 436},
#     {'name': 'City6 Attraction 3', 'rating': 3.5, 'price': 168},
#     {'name': 'City6 Attraction 4', 'rating': 4.5, 'price': 169},
#     {'name': 'City6 Attraction 5', 'rating': 4.6, 'price': 188}]},
#   {'city': 'City7',
#    'attractions': [{'name': 'City7 Attraction 1', 'rating': 4.8, 'price': 409},
#     {'name': 'City7 Attraction 2', 'rating': 4.5, 'price': 207},
#     {'name': 'City7 Attraction 3', 'rating': 4.3, 'price': 301},
#     {'name': 'City7 Attraction 4', 'rating': 3.9, 'price': 237},
#     {'name': 'City7 Attraction 5', 'rating': 4.9, 'price': 446}]},
#   {'city': 'City8',
#    'attractions': [{'name': 'City8 Attraction 1', 'rating': 3.6, 'price': 215},
#     {'name': 'City8 Attraction 2', 'rating': 4.0, 'price': 385},
#     {'name': 'City8 Attraction 3', 'rating': 4.9, 'price': 422},
#     {'name': 'City8 Attraction 4', 'rating': 4.2, 'price': 331},
#     {'name': 'City8 Attraction 5', 'rating': 3.7, 'price': 284}]},
#   {'city': 'City9',
#    'attractions': [{'name': 'City9 Attraction 1', 'rating': 4.0, 'price': 348},
#     {'name': 'City9 Attraction 2', 'rating': 3.8, 'price': 188},
#     {'name': 'City9 Attraction 3', 'rating': 4.0, 'price': 433},
#     {'name': 'City9 Attraction 4', 'rating': 4.3, 'price': 274},
#     {'name': 'City9 Attraction 5', 'rating': 4.9, 'price': 267}]},
#   {'city': 'City10',
#    'attractions': [{'name': 'City10 Attraction 1',
#      'rating': 4.1,
#      'price': 357},
#     {'name': 'City10 Attraction 2', 'rating': 4.5, 'price': 431},
#     {'name': 'City10 Attraction 3', 'rating': 3.9, 'price': 305},
#     {'name': 'City10 Attraction 4', 'rating': 3.8, 'price': 112},
#     {'name': 'City10 Attraction 5', 'rating': 3.7, 'price': 241}]}],
#  [{'city': 'City1',
#    'restaurant_name': 'City1 Restaurant 1',
#    'rating': 4.4,
#    'price': 208},
#   {'city': 'City1',
#    'restaurant_name': 'City1 Restaurant 2',
#    'rating': 4.9,
#    'price': 340},
#   {'city': 'City1',
#    'restaurant_name': 'City1 Restaurant 3',
#    'rating': 4.9,
#    'price': 273},
#   {'city': 'City1',
#    'restaurant_name': 'City1 Restaurant 4',
#    'rating': 3.2,
#    'price': 525},
#   {'city': 'City2',
#    'restaurant_name': 'City2 Restaurant 1',
#    'rating': 4.1,
#    'price': 271},
#   {'city': 'City2',
#    'restaurant_name': 'City2 Restaurant 2',
#    'rating': 3.8,
#    'price': 153},
#   {'city': 'City2',
#    'restaurant_name': 'City2 Restaurant 3',
#    'rating': 3.7,
#    'price': 484},
#   {'city': 'City2',
#    'restaurant_name': 'City2 Restaurant 4',
#    'rating': 4.1,
#    'price': 233},
#   {'city': 'City3',
#    'restaurant_name': 'City3 Restaurant 1',
#    'rating': 4.0,
#    'price': 352},
#   {'city': 'City3',
#    'restaurant_name': 'City3 Restaurant 2',
#    'rating': 4.6,
#    'price': 331},
#   {'city': 'City3',
#    'restaurant_name': 'City3 Restaurant 3',
#    'rating': 4.2,
#    'price': 172},
#   {'city': 'City3',
#    'restaurant_name': 'City3 Restaurant 4',
#    'rating': 3.7,
#    'price': 579},
#   {'city': 'City4',
#    'restaurant_name': 'City4 Restaurant 1',
#    'rating': 3.8,
#    'price': 226},
#   {'city': 'City4',
#    'restaurant_name': 'City4 Restaurant 2',
#    'rating': 4.1,
#    'price': 174},
#   {'city': 'City4',
#    'restaurant_name': 'City4 Restaurant 3',
#    'rating': 3.4,
#    'price': 240},
#   {'city': 'City4',
#    'restaurant_name': 'City4 Restaurant 4',
#    'rating': 4.5,
#    'price': 470},
#   {'city': 'City5',
#    'restaurant_name': 'City5 Restaurant 1',
#    'rating': 3.2,
#    'price': 257},
#   {'city': 'City5',
#    'restaurant_name': 'City5 Restaurant 2',
#    'rating': 4.8,
#    'price': 264},
#   {'city': 'City5',
#    'restaurant_name': 'City5 Restaurant 3',
#    'rating': 4.9,
#    'price': 483},
#   {'city': 'City5',
#    'restaurant_name': 'City5 Restaurant 4',
#    'rating': 3.4,
#    'price': 450},
#   {'city': 'City6',
#    'restaurant_name': 'City6 Restaurant 1',
#    'rating': 4.7,
#    'price': 516},
#   {'city': 'City6',
#    'restaurant_name': 'City6 Restaurant 2',
#    'rating': 4.6,
#    'price': 528},
#   {'city': 'City6',
#    'restaurant_name': 'City6 Restaurant 3',
#    'rating': 3.1,
#    'price': 491},
#   {'city': 'City6',
#    'restaurant_name': 'City6 Restaurant 4',
#    'rating': 4.4,
#    'price': 600},
#   {'city': 'City7',
#    'restaurant_name': 'City7 Restaurant 1',
#    'rating': 4.1,
#    'price': 499},
#   {'city': 'City7',
#    'restaurant_name': 'City7 Restaurant 2',
#    'rating': 3.3,
#    'price': 274},
#   {'city': 'City7',
#    'restaurant_name': 'City7 Restaurant 3',
#    'rating': 4.8,
#    'price': 212},
#   {'city': 'City7',
#    'restaurant_name': 'City7 Restaurant 4',
#    'rating': 4.4,
#    'price': 153},
#   {'city': 'City8',
#    'restaurant_name': 'City8 Restaurant 1',
#    'rating': 4.2,
#    'price': 529},
#   {'city': 'City8',
#    'restaurant_name': 'City8 Restaurant 2',
#    'rating': 3.2,
#    'price': 519},
#   {'city': 'City8',
#    'restaurant_name': 'City8 Restaurant 3',
#    'rating': 3.2,
#    'price': 154},
#   {'city': 'City8',
#    'restaurant_name': 'City8 Restaurant 4',
#    'rating': 3.4,
#    'price': 463},
#   {'city': 'City9',
#    'restaurant_name': 'City9 Restaurant 1',
#    'rating': 4.5,
#    'price': 237},
#   {'city': 'City9',
#    'restaurant_name': 'City9 Restaurant 2',
#    'rating': 4.8,
#    'price': 478},
#   {'city': 'City9',
#    'restaurant_name': 'City9 Restaurant 3',
#    'rating': 3.5,
#    'price': 476},
#   {'city': 'City9',
#    'restaurant_name': 'City9 Restaurant 4',
#    'rating': 4.4,
#    'price': 528},
#   {'city': 'City10',
#    'restaurant_name': 'City10 Restaurant 1',
#    'rating': 3.1,
#    'price': 448},
#   {'city': 'City10',
#    'restaurant_name': 'City10 Restaurant 2',
#    'rating': 4.8,
#    'price': 460},
#   {'city': 'City10',
#    'restaurant_name': 'City10 Restaurant 3',
#    'rating': 3.7,
#    'price': 492},
#   {'city': 'City10',
#    'restaurant_name': 'City10 Restaurant 4',
#    'rating': 4.1,
#    'price': 594}],
#  [{'city': 'City1',
#    'hotels': [{'name': 'City1 Hotel 1', 'price_per_night': 2525},
#     {'name': 'City1 Hotel 2', 'price_per_night': 2208},
#     {'name': 'City1 Hotel 3', 'price_per_night': 1069}]},
#   {'city': 'City2',
#    'hotels': [{'name': 'City2 Hotel 1', 'price_per_night': 1454},
#     {'name': 'City2 Hotel 2', 'price_per_night': 2030},
#     {'name': 'City2 Hotel 3', 'price_per_night': 1985}]},
#   {'city': 'City3',
#    'hotels': [{'name': 'City3 Hotel 1', 'price_per_night': 2843},
#     {'name': 'City3 Hotel 2', 'price_per_night': 2035},
#     {'name': 'City3 Hotel 3', 'price_per_night': 1367}]},
#   {'city': 'City4',
#    'hotels': [{'name': 'City4 Hotel 1', 'price_per_night': 1504},
#     {'name': 'City4 Hotel 2', 'price_per_night': 2072},
#     {'name': 'City4 Hotel 3', 'price_per_night': 1164}]},
#   {'city': 'City5',
#    'hotels': [{'name': 'City5 Hotel 1', 'price_per_night': 2776},
#     {'name': 'City5 Hotel 2', 'price_per_night': 2893},
#     {'name': 'City5 Hotel 3', 'price_per_night': 1000}]},
#   {'city': 'City6',
#    'hotels': [{'name': 'City6 Hotel 1', 'price_per_night': 1430},
#     {'name': 'City6 Hotel 2', 'price_per_night': 2956},
#     {'name': 'City6 Hotel 3', 'price_per_night': 2651}]},
#   {'city': 'City7',
#    'hotels': [{'name': 'City7 Hotel 1', 'price_per_night': 1638},
#     {'name': 'City7 Hotel 2', 'price_per_night': 1611},
#     {'name': 'City7 Hotel 3', 'price_per_night': 2798}]},
#   {'city': 'City8',
#    'hotels': [{'name': 'City8 Hotel 1', 'price_per_night': 2034},
#     {'name': 'City8 Hotel 2', 'price_per_night': 2349},
#     {'name': 'City8 Hotel 3', 'price_per_night': 1530}]},
#   {'city': 'City9',
#    'hotels': [{'name': 'City9 Hotel 1', 'price_per_night': 1878},
#     {'name': 'City9 Hotel 2', 'price_per_night': 1133},
#     {'name': 'City9 Hotel 3', 'price_per_night': 2262}]},
#   {'city': 'City10',
#    'hotels': [{'name': 'City10 Hotel 1', 'price_per_night': 2243},
#     {'name': 'City10 Hotel 2', 'price_per_night': 1790},
#     {'name': 'City10 Hotel 3', 'price_per_night': 2770}]}],
#  [{'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City1',
#    'flight_to': 'City2',
#    'price': 3660,
#    'duration_hr': 1.7},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City1',
#    'flight_to': 'City2',
#    'price': 1712,
#    'duration_hr': 1.6},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City1',
#    'flight_to': 'City3',
#    'price': 4910,
#    'duration_hr': 1.7},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City1',
#    'flight_to': 'City3',
#    'price': 4030,
#    'duration_hr': 2.2},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City1',
#    'flight_to': 'City4',
#    'price': 2497,
#    'duration_hr': 1.7},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City1',
#    'flight_to': 'City4',
#    'price': 2823,
#    'duration_hr': 2.9},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City1',
#    'flight_to': 'City5',
#    'price': 4156,
#    'duration_hr': 2.1},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City1',
#    'flight_to': 'City5',
#    'price': 4818,
#    'duration_hr': 3.2},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City1',
#    'flight_to': 'City6',
#    'price': 4334,
#    'duration_hr': 3.5},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City1',
#    'flight_to': 'City6',
#    'price': 3131,
#    'duration_hr': 3.3},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City1',
#    'flight_to': 'City7',
#    'price': 3905,
#    'duration_hr': 1.6},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City1',
#    'flight_to': 'City7',
#    'price': 4107,
#    'duration_hr': 1.9},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City1',
#    'flight_to': 'City8',
#    'price': 3543,
#    'duration_hr': 1.9},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City1',
#    'flight_to': 'City8',
#    'price': 4928,
#    'duration_hr': 3.2},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City1',
#    'flight_to': 'City9',
#    'price': 1555,
#    'duration_hr': 2.0},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City1',
#    'flight_to': 'City9',
#    'price': 3595,
#    'duration_hr': 3.3},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City1',
#    'flight_to': 'City10',
#    'price': 4787,
#    'duration_hr': 2.0},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City1',
#    'flight_to': 'City10',
#    'price': 4034,
#    'duration_hr': 3.4},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City2',
#    'flight_to': 'City1',
#    'price': 2788,
#    'duration_hr': 3.9},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City2',
#    'flight_to': 'City1',
#    'price': 4883,
#    'duration_hr': 1.1},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City2',
#    'flight_to': 'City3',
#    'price': 3695,
#    'duration_hr': 1.7},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City2',
#    'flight_to': 'City3',
#    'price': 1622,
#    'duration_hr': 2.7},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City2',
#    'flight_to': 'City4',
#    'price': 2673,
#    'duration_hr': 1.7},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City2',
#    'flight_to': 'City4',
#    'price': 4317,
#    'duration_hr': 1.2},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City2',
#    'flight_to': 'City5',
#    'price': 4914,
#    'duration_hr': 2.4},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City2',
#    'flight_to': 'City5',
#    'price': 3115,
#    'duration_hr': 1.0},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City2',
#    'flight_to': 'City6',
#    'price': 4479,
#    'duration_hr': 3.1},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City2',
#    'flight_to': 'City6',
#    'price': 3841,
#    'duration_hr': 2.8},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City2',
#    'flight_to': 'City7',
#    'price': 3120,
#    'duration_hr': 2.8},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City2',
#    'flight_to': 'City7',
#    'price': 2463,
#    'duration_hr': 1.1},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City2',
#    'flight_to': 'City8',
#    'price': 2201,
#    'duration_hr': 1.9},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City2',
#    'flight_to': 'City8',
#    'price': 2653,
#    'duration_hr': 1.4},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City2',
#    'flight_to': 'City9',
#    'price': 2687,
#    'duration_hr': 2.0},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City2',
#    'flight_to': 'City9',
#    'price': 2946,
#    'duration_hr': 3.5},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City2',
#    'flight_to': 'City10',
#    'price': 1863,
#    'duration_hr': 2.1},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City2',
#    'flight_to': 'City10',
#    'price': 1735,
#    'duration_hr': 3.5},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City3',
#    'flight_to': 'City1',
#    'price': 3084,
#    'duration_hr': 1.4},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City3',
#    'flight_to': 'City1',
#    'price': 4705,
#    'duration_hr': 1.2},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City3',
#    'flight_to': 'City2',
#    'price': 3586,
#    'duration_hr': 2.6},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City3',
#    'flight_to': 'City2',
#    'price': 3668,
#    'duration_hr': 3.1},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City3',
#    'flight_to': 'City4',
#    'price': 2852,
#    'duration_hr': 1.2},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City3',
#    'flight_to': 'City4',
#    'price': 3170,
#    'duration_hr': 2.9},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City3',
#    'flight_to': 'City5',
#    'price': 2204,
#    'duration_hr': 1.2},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City3',
#    'flight_to': 'City5',
#    'price': 3355,
#    'duration_hr': 1.4},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City3',
#    'flight_to': 'City6',
#    'price': 3482,
#    'duration_hr': 2.1},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City3',
#    'flight_to': 'City6',
#    'price': 3289,
#    'duration_hr': 2.6},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City3',
#    'flight_to': 'City7',
#    'price': 1857,
#    'duration_hr': 2.4},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City3',
#    'flight_to': 'City7',
#    'price': 2984,
#    'duration_hr': 2.0},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City3',
#    'flight_to': 'City8',
#    'price': 2241,
#    'duration_hr': 2.4},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City3',
#    'flight_to': 'City8',
#    'price': 2364,
#    'duration_hr': 1.0},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City3',
#    'flight_to': 'City9',
#    'price': 2699,
#    'duration_hr': 2.1},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City3',
#    'flight_to': 'City9',
#    'price': 2276,
#    'duration_hr': 3.2},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City3',
#    'flight_to': 'City10',
#    'price': 3304,
#    'duration_hr': 1.3},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City3',
#    'flight_to': 'City10',
#    'price': 4932,
#    'duration_hr': 3.7},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City4',
#    'flight_to': 'City1',
#    'price': 2303,
#    'duration_hr': 3.9},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City4',
#    'flight_to': 'City1',
#    'price': 4167,
#    'duration_hr': 3.0},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City4',
#    'flight_to': 'City2',
#    'price': 2320,
#    'duration_hr': 1.8},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City4',
#    'flight_to': 'City2',
#    'price': 1862,
#    'duration_hr': 2.0},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City4',
#    'flight_to': 'City3',
#    'price': 4849,
#    'duration_hr': 1.6},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City4',
#    'flight_to': 'City3',
#    'price': 4355,
#    'duration_hr': 3.0},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City4',
#    'flight_to': 'City5',
#    'price': 2251,
#    'duration_hr': 2.1},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City4',
#    'flight_to': 'City5',
#    'price': 4472,
#    'duration_hr': 1.8},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City4',
#    'flight_to': 'City6',
#    'price': 2367,
#    'duration_hr': 2.4},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City4',
#    'flight_to': 'City6',
#    'price': 3786,
#    'duration_hr': 1.2},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City4',
#    'flight_to': 'City7',
#    'price': 3893,
#    'duration_hr': 2.5},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City4',
#    'flight_to': 'City7',
#    'price': 2591,
#    'duration_hr': 1.7},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City4',
#    'flight_to': 'City8',
#    'price': 2830,
#    'duration_hr': 3.0},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City4',
#    'flight_to': 'City8',
#    'price': 1786,
#    'duration_hr': 3.5},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City4',
#    'flight_to': 'City9',
#    'price': 4768,
#    'duration_hr': 1.8},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City4',
#    'flight_to': 'City9',
#    'price': 2193,
#    'duration_hr': 1.6},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City4',
#    'flight_to': 'City10',
#    'price': 2673,
#    'duration_hr': 3.6},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City4',
#    'flight_to': 'City10',
#    'price': 1787,
#    'duration_hr': 1.2},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City5',
#    'flight_to': 'City1',
#    'price': 3173,
#    'duration_hr': 2.3},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City5',
#    'flight_to': 'City1',
#    'price': 3405,
#    'duration_hr': 3.3},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City5',
#    'flight_to': 'City2',
#    'price': 4739,
#    'duration_hr': 2.3},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City5',
#    'flight_to': 'City2',
#    'price': 1756,
#    'duration_hr': 3.4},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City5',
#    'flight_to': 'City3',
#    'price': 3175,
#    'duration_hr': 2.1},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City5',
#    'flight_to': 'City3',
#    'price': 4884,
#    'duration_hr': 1.6},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City5',
#    'flight_to': 'City4',
#    'price': 2920,
#    'duration_hr': 2.1},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City5',
#    'flight_to': 'City4',
#    'price': 3863,
#    'duration_hr': 3.7},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City5',
#    'flight_to': 'City6',
#    'price': 2099,
#    'duration_hr': 2.0},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City5',
#    'flight_to': 'City6',
#    'price': 2582,
#    'duration_hr': 2.6},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City5',
#    'flight_to': 'City7',
#    'price': 4862,
#    'duration_hr': 1.8},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City5',
#    'flight_to': 'City7',
#    'price': 2142,
#    'duration_hr': 2.7},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City5',
#    'flight_to': 'City8',
#    'price': 1784,
#    'duration_hr': 1.1},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City5',
#    'flight_to': 'City8',
#    'price': 2372,
#    'duration_hr': 3.4},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City5',
#    'flight_to': 'City9',
#    'price': 4616,
#    'duration_hr': 2.6},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City5',
#    'flight_to': 'City9',
#    'price': 2051,
#    'duration_hr': 3.8},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City5',
#    'flight_to': 'City10',
#    'price': 4192,
#    'duration_hr': 2.6},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City5',
#    'flight_to': 'City10',
#    'price': 2772,
#    'duration_hr': 1.8},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City6',
#    'flight_to': 'City1',
#    'price': 4504,
#    'duration_hr': 1.8},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City6',
#    'flight_to': 'City1',
#    'price': 2545,
#    'duration_hr': 1.5},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City6',
#    'flight_to': 'City2',
#    'price': 4407,
#    'duration_hr': 2.3},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City6',
#    'flight_to': 'City2',
#    'price': 2768,
#    'duration_hr': 1.4},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City6',
#    'flight_to': 'City3',
#    'price': 3358,
#    'duration_hr': 1.9},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City6',
#    'flight_to': 'City3',
#    'price': 3246,
#    'duration_hr': 3.5},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City6',
#    'flight_to': 'City4',
#    'price': 1993,
#    'duration_hr': 3.9},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City6',
#    'flight_to': 'City4',
#    'price': 4883,
#    'duration_hr': 2.8},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City6',
#    'flight_to': 'City5',
#    'price': 2330,
#    'duration_hr': 1.7},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City6',
#    'flight_to': 'City5',
#    'price': 3033,
#    'duration_hr': 4.0},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City6',
#    'flight_to': 'City7',
#    'price': 4148,
#    'duration_hr': 1.6},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City6',
#    'flight_to': 'City7',
#    'price': 2521,
#    'duration_hr': 2.9},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City6',
#    'flight_to': 'City8',
#    'price': 1788,
#    'duration_hr': 1.7},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City6',
#    'flight_to': 'City8',
#    'price': 3969,
#    'duration_hr': 1.6},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City6',
#    'flight_to': 'City9',
#    'price': 3784,
#    'duration_hr': 2.0},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City6',
#    'flight_to': 'City9',
#    'price': 2991,
#    'duration_hr': 3.4},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City6',
#    'flight_to': 'City10',
#    'price': 4846,
#    'duration_hr': 3.9},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City6',
#    'flight_to': 'City10',
#    'price': 1788,
#    'duration_hr': 3.6},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City7',
#    'flight_to': 'City1',
#    'price': 3265,
#    'duration_hr': 2.8},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City7',
#    'flight_to': 'City1',
#    'price': 4612,
#    'duration_hr': 1.8},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City7',
#    'flight_to': 'City2',
#    'price': 4503,
#    'duration_hr': 3.2},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City7',
#    'flight_to': 'City2',
#    'price': 4497,
#    'duration_hr': 2.5},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City7',
#    'flight_to': 'City3',
#    'price': 2563,
#    'duration_hr': 2.1},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City7',
#    'flight_to': 'City3',
#    'price': 2977,
#    'duration_hr': 2.9},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City7',
#    'flight_to': 'City4',
#    'price': 2225,
#    'duration_hr': 2.7},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City7',
#    'flight_to': 'City4',
#    'price': 3681,
#    'duration_hr': 3.6},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City7',
#    'flight_to': 'City5',
#    'price': 3731,
#    'duration_hr': 3.8},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City7',
#    'flight_to': 'City5',
#    'price': 2546,
#    'duration_hr': 1.8},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City7',
#    'flight_to': 'City6',
#    'price': 3987,
#    'duration_hr': 2.8},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City7',
#    'flight_to': 'City6',
#    'price': 4910,
#    'duration_hr': 1.4},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City7',
#    'flight_to': 'City8',
#    'price': 3975,
#    'duration_hr': 3.6},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City7',
#    'flight_to': 'City8',
#    'price': 3061,
#    'duration_hr': 2.2},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City7',
#    'flight_to': 'City9',
#    'price': 4713,
#    'duration_hr': 3.3},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City7',
#    'flight_to': 'City9',
#    'price': 2680,
#    'duration_hr': 1.8},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City7',
#    'flight_to': 'City10',
#    'price': 2457,
#    'duration_hr': 1.4},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City7',
#    'flight_to': 'City10',
#    'price': 4230,
#    'duration_hr': 3.5},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City8',
#    'flight_to': 'City1',
#    'price': 4621,
#    'duration_hr': 3.1},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City8',
#    'flight_to': 'City1',
#    'price': 4220,
#    'duration_hr': 2.5},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City8',
#    'flight_to': 'City2',
#    'price': 3653,
#    'duration_hr': 1.5},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City8',
#    'flight_to': 'City2',
#    'price': 2255,
#    'duration_hr': 2.3},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City8',
#    'flight_to': 'City3',
#    'price': 3553,
#    'duration_hr': 3.6},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City8',
#    'flight_to': 'City3',
#    'price': 4311,
#    'duration_hr': 3.4},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City8',
#    'flight_to': 'City4',
#    'price': 3774,
#    'duration_hr': 2.4},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City8',
#    'flight_to': 'City4',
#    'price': 2672,
#    'duration_hr': 2.6},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City8',
#    'flight_to': 'City5',
#    'price': 4093,
#    'duration_hr': 3.4},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City8',
#    'flight_to': 'City5',
#    'price': 4752,
#    'duration_hr': 2.6},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City8',
#    'flight_to': 'City6',
#    'price': 2119,
#    'duration_hr': 2.9},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City8',
#    'flight_to': 'City6',
#    'price': 2206,
#    'duration_hr': 2.2},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City8',
#    'flight_to': 'City7',
#    'price': 2380,
#    'duration_hr': 2.4},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City8',
#    'flight_to': 'City7',
#    'price': 4846,
#    'duration_hr': 1.4},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City8',
#    'flight_to': 'City9',
#    'price': 3640,
#    'duration_hr': 3.0},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City8',
#    'flight_to': 'City9',
#    'price': 4330,
#    'duration_hr': 1.8},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City8',
#    'flight_to': 'City10',
#    'price': 3624,
#    'duration_hr': 2.5},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City8',
#    'flight_to': 'City10',
#    'price': 4238,
#    'duration_hr': 3.6},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City9',
#    'flight_to': 'City1',
#    'price': 4280,
#    'duration_hr': 1.4},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City9',
#    'flight_to': 'City1',
#    'price': 2075,
#    'duration_hr': 3.1},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City9',
#    'flight_to': 'City2',
#    'price': 2544,
#    'duration_hr': 1.4},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City9',
#    'flight_to': 'City2',
#    'price': 3948,
#    'duration_hr': 1.3},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City9',
#    'flight_to': 'City3',
#    'price': 4233,
#    'duration_hr': 2.7},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City9',
#    'flight_to': 'City3',
#    'price': 2881,
#    'duration_hr': 1.3},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City9',
#    'flight_to': 'City4',
#    'price': 3304,
#    'duration_hr': 2.0},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City9',
#    'flight_to': 'City4',
#    'price': 2785,
#    'duration_hr': 3.4},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City9',
#    'flight_to': 'City5',
#    'price': 3841,
#    'duration_hr': 2.7},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City9',
#    'flight_to': 'City5',
#    'price': 1909,
#    'duration_hr': 3.6},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City9',
#    'flight_to': 'City6',
#    'price': 4542,
#    'duration_hr': 1.8},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City9',
#    'flight_to': 'City6',
#    'price': 4742,
#    'duration_hr': 3.0},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City9',
#    'flight_to': 'City7',
#    'price': 2101,
#    'duration_hr': 2.4},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City9',
#    'flight_to': 'City7',
#    'price': 1806,
#    'duration_hr': 1.6},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City9',
#    'flight_to': 'City8',
#    'price': 4508,
#    'duration_hr': 2.3},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City9',
#    'flight_to': 'City8',
#    'price': 1841,
#    'duration_hr': 2.7},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City9',
#    'flight_to': 'City10',
#    'price': 4844,
#    'duration_hr': 3.3},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City9',
#    'flight_to': 'City10',
#    'price': 2789,
#    'duration_hr': 1.1},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City10',
#    'flight_to': 'City1',
#    'price': 3324,
#    'duration_hr': 1.1},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City10',
#    'flight_to': 'City1',
#    'price': 1657,
#    'duration_hr': 4.0},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City10',
#    'flight_to': 'City2',
#    'price': 2941,
#    'duration_hr': 2.8},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City10',
#    'flight_to': 'City2',
#    'price': 4586,
#    'duration_hr': 3.7},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City10',
#    'flight_to': 'City3',
#    'price': 1719,
#    'duration_hr': 3.7},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City10',
#    'flight_to': 'City3',
#    'price': 2500,
#    'duration_hr': 3.8},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City10',
#    'flight_to': 'City4',
#    'price': 2701,
#    'duration_hr': 3.8},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City10',
#    'flight_to': 'City4',
#    'price': 4904,
#    'duration_hr': 1.4},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City10',
#    'flight_to': 'City5',
#    'price': 2685,
#    'duration_hr': 1.1},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City10',
#    'flight_to': 'City5',
#    'price': 3240,
#    'duration_hr': 3.4},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City10',
#    'flight_to': 'City6',
#    'price': 1888,
#    'duration_hr': 1.1},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City10',
#    'flight_to': 'City6',
#    'price': 3805,
#    'duration_hr': 2.7},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City10',
#    'flight_to': 'City7',
#    'price': 3689,
#    'duration_hr': 3.4},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City10',
#    'flight_to': 'City7',
#    'price': 4397,
#    'duration_hr': 2.9},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City10',
#    'flight_to': 'City8',
#    'price': 2096,
#    'duration_hr': 2.0},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City10',
#    'flight_to': 'City8',
#    'price': 2823,
#    'duration_hr': 3.3},
#   {'flight_name': 'Cit-Cit-1',
#    'flight_from': 'City10',
#    'flight_to': 'City9',
#    'price': 4117,
#    'duration_hr': 2.7},
#   {'flight_name': 'Cit-Cit-2',
#    'flight_from': 'City10',
#    'flight_to': 'City9',
#    'price': 4075,
#    'duration_hr': 1.9}])

# %% [markdown]
# Here’s what we now have ready:
#
# ✔️ Generated JSON Structures:
# Attractions JSON – 5 attractions per city with name, rating, and price
#
# Restaurants JSON – 4 restaurants per city with name, rating, and price
#
# Hotels JSON – 3 hotels per city with name and price per night
#
# Flights JSON – 2 flights between each city pair (full permutation of 10 cities = 90 pairs → 180 flight options)

# %% [markdown]
# 🚀 Next Step:
# We will now use this data to run the entire end-to-end pipeline, including:
#
# City scoring based on attraction, food, and affordability
#
# Selecting top N cities (e.g., 5)
#
# Route optimization based on flight costs
#
# Day allocation per city
#
# Budget estimation
#
# Day-by-day itinerary creation
#
# Final RAG input structure generation

# %%
! pip install ace_tools
# Out:
# Requirement already satisfied: ace_tools in /opt/anaconda3/lib/python3.12/site-packages (0.0)

# %%
import pandas as pd
from collections import defaultdict

# -------------------------------
# Step 1: City Scoring
# -------------------------------

city_scores = {}

for city in cities:
    # Attractions
    city_attractions = next(item['attractions'] for item in attractions_json if item['city'] == city)
    avg_attraction_rating = sum(a['rating'] for a in city_attractions) / len(city_attractions)
    total_attraction_price = sum(a['price'] for a in city_attractions)

    # Restaurants
    city_restaurants = [r for r in restaurants_json if r['city'] == city]
    avg_restaurant_rating = sum(r['rating'] for r in city_restaurants) / len(city_restaurants)
    avg_food_price = sum(r['price'] for r in city_restaurants) / len(city_restaurants)

    # Hotels
    city_hotels = next(item['hotels'] for item in hotels_json if item['city'] == city)
    avg_hotel_price = sum(h['price_per_night'] for h in city_hotels) / len(city_hotels)

    # Composite Score
    score = (
        0.4 * avg_attraction_rating +
        0.3 * avg_restaurant_rating +
        0.3 * (1 / (avg_hotel_price + avg_food_price + total_attraction_price)) * 10000
    )
    city_scores[city] = {
        "score": score,
        "avg_attraction_rating": avg_attraction_rating,
        "avg_restaurant_rating": avg_restaurant_rating,
        "avg_hotel_price": avg_hotel_price,
        "avg_food_price": avg_food_price,
        "total_attraction_price": total_attraction_price
    }

# Select top 5 cities
top_cities = sorted(city_scores.items(), key=lambda x: x[1]['score'], reverse=True)[:5]
selected_cities = [city for city, _ in top_cities]

# -------------------------------
# Step 2: Route Optimization (Greedy)
# -------------------------------

# Build city-to-city cost map
flight_map = defaultdict(lambda: defaultdict(list))
for flight in flights_json:
    if flight['flight_from'] in selected_cities and flight['flight_to'] in selected_cities:
        flight_map[flight['flight_from']][flight['flight_to']].append(flight)

# Pick cheapest flight between cities
flight_costs = {
    (src, dst): min(flight_map[src][dst], key=lambda f: f['price'])
    for src in selected_cities for dst in selected_cities if src != dst and dst in flight_map[src]
}

# Simple greedy TSP
start_city = selected_cities[0]
unvisited = set(selected_cities)
route = [start_city]
unvisited.remove(start_city)

current_city = start_city
while unvisited:
    next_city = min(unvisited, key=lambda c: flight_costs[(current_city, c)]['price'] if (current_city, c) in flight_costs else float('inf'))
    route.append(next_city)
    unvisited.remove(next_city)
    current_city = next_city

# -------------------------------
# Step 3: Day Allocation
# -------------------------------

total_days = 8
base_days = {city: 1 for city in route}
remaining_days = total_days - len(route)

# Allocate extra days to cities with higher attraction rating
while remaining_days > 0:
    best_city = max(route, key=lambda c: city_scores[c]["avg_attraction_rating"])
    base_days[best_city] += 1
    remaining_days -= 1

# -------------------------------
# Step 4: Budget Calculation
# -------------------------------

budget = 200000  # INR

itinerary = []
total_hotel_cost = 0
total_food_cost = 0
total_attraction_cost = 0
total_flight_cost = 0

for i, city in enumerate(route):
    days = base_days[city]
    hotel_cost = city_scores[city]["avg_hotel_price"] * days
    food_cost = city_scores[city]["avg_food_price"] * 3 * days
    attraction_cost = city_scores[city]["total_attraction_price"]

    total_hotel_cost += hotel_cost
    total_food_cost += food_cost
    total_attraction_cost += attraction_cost

    # Flights between cities
    if i < len(route) - 1:
        f = flight_costs[(city, route[i + 1])]
        total_flight_cost += f['price']

    # Day-wise itinerary
    city_attractions = next(item['attractions'] for item in attractions_json if item['city'] == city)
    city_restaurants = [r for r in restaurants_json if r['city'] == city]
    for day in range(days):
        attractions_today = random.sample(city_attractions, 3)
        restaurant = random.choice(city_restaurants)
        itinerary.append({
            "day": len(itinerary) + 1,
            "city": city,
            "attractions": [a['name'] for a in attractions_today],
            "restaurant": restaurant['restaurant_name'],
            "notes": f"Enjoy dinner at {restaurant['restaurant_name']} rated {restaurant['rating']}"
        })

# -------------------------------
# Step 5: RAG Input Preparation
# -------------------------------

rag_input = {
    "user_info": {
        "destination": "India",
        "budget_in_inr": budget,
        "from_date": "2025-05-20",
        "to_date": "2025-05-28"
    },
    "selected_cities": route,
    "days_allocation": base_days,
    "daily_itinerary": itinerary,
    "costs": {
        "hotel": total_hotel_cost,
        "food": total_food_cost,
        "attraction": total_attraction_cost,
        "flights": total_flight_cost,
        "total_estimated": total_hotel_cost + total_food_cost + total_attraction_cost + total_flight_cost
    }
}

with open("final_rag_input.json", "w") as f:
    json.dump(rag_input, f, indent=4)

print("✔️ RAG input saved to final_rag_input.json")
# Out:
# ✔️ RAG input saved to final_rag_input.json
