# %%
import asyncio
import aiohttp
import json
from pprint import pprint

from attraction_api import fetch_attractions
from hotel_api import HotelRetriever
from flight_api import FlightRetriever
from llm_retrieve import llm_retrieve

# %%
itinerary = llm_retrieve()
print("Loaded cities and parameters:")
for city, info in itinerary.items():
    print(f" • {city}: Arrival={info['Arrival Date']}, Departure={info['Departure Date']}, Airport={info['Airport']}")
# Out:
# Loaded cities and parameters:
#  • Srinagar: Arrival=2025-07-12, Departure=2025-07-14, Airport=SXR
#  • Leh: Arrival=2025-07-14, Departure=2025-07-16, Airport=IXL
#  • Shimla: Arrival=2025-07-16, Departure=2025-07-19, Airport=SLV

# %%
async def gather_all():
    async with aiohttp.ClientSession() as session:
        attraction_tasks = [fetch_attractions(session, city) for city in itinerary.keys()]
        attraction_results = await asyncio.gather(*attraction_tasks)

    hotel_results = HotelRetriever(itinerary, numadults=2)
    flight_results = FlightRetriever(itinerary)

    return attraction_results, hotel_results, flight_results

# %%
# Cell 4: Run & Merge
attractions, hotels, flights = await gather_all()

# Merge results by city
combined = {city: {"city": city, "attractions": [], "hotels": [], "flights": []} for city in itinerary}

# Add attractions
for entry in attractions:
    combined[entry["city"]]["attractions"] = entry["attractions"]

# Add hotels
for entry in hotels:
    city = entry["city"]
    combined[city]["hotels"] = entry["hotels_by"]

# Add flights
for entry in flights:
    from_city = entry["from"]
    to_city = entry["to"]
    date = entry["date"]
    flights_data = entry.get("flights")
    note = entry.get("note")

    # Associate the flight with departure city
    combined[from_city].setdefault("flights", []).append({
        "to": to_city,
        "date": date,
        "flights": flights_data,
        "note": note
    })

# Add user input fields after merging
traveller_count = 4  # set manually or collect from UI
for city, meta in itinerary.items():
    if city in combined:
        combined[city]["arrival_date"] = meta["Arrival Date"]
        combined[city]["departure_date"] = meta["Departure Date"]
        combined[city]["airport"] = meta["Airport"]
        combined[city]["travellers"] = traveller_count
# Out:
# [Attraction] 🔍 Fetching location_id for: Srinagar
# [Attraction] 🔍 Fetching location_id for: Leh
# [Attraction] 🔍 Fetching location_id for: Shimla
# [Attraction] ✅ location_id for Srinagar = 297623
# [Attraction] 🔍 Fetching attractions for Srinagar
# [Attraction] ✅ location_id for Shimla = 304552
# [Attraction] 🔍 Fetching attractions for Shimla
# [Attraction] ✅ location_id for Leh = 4266551
# [Attraction] 🔍 Fetching attractions for Leh
# [Attraction] 🌐 Raw results count for Srinagar: 20
# [Attraction] 🎯 Returning 10 attractions for Srinagar
# [Attraction] 🌐 Raw results count for Shimla: 20
# [Attraction] 🎯 Returning 10 attractions for Shimla
# [Attraction] 🌐 Raw results count for Leh: 20
# [Attraction] 🎯 Returning 10 attractions for Leh

# %%
final_list = list(combined.values())

print("\n\u2705 After merging, sample output for first city:")
print(json.dumps(final_list[0], indent=2))
# Out:
# ✅ After merging, sample output for first city:
# {
#   "city": "Srinagar",
#   "attractions": [
#     {
#       "name": "Dal Lake",
#       "num_reviews": "4329",
#       "rating": "4.3",
#       "ranking_position": "6",
#       "neighborhood_info": null,
#       "description": "",
#       "subcategory": [
#         {
#           "key": "57",
#           "name": "Nature & Parks"
#         }
#       ]
#     },
#     {
#       "name": "Indira Gandhi Tulip Garden",
#       "num_reviews": "1146",
#       "rating": "4.6",
#       "ranking_position": "2",
#       "neighborhood_info": null,
#       "description": "",
#       "subcategory": [
#         {
#           "key": "57",
#           "name": "Nature & Parks"
#         }
#       ]
#     },
#     {
#       "name": "Sonamarg Hill Station",
#       "num_reviews": "1174",
#       "rating": "4.4",
#       "ranking_position": "4",
#       "neighborhood_info": null,
#       "description": "",
#       "subcategory": [
#         {
#           "key": "57",
#           "name": "Nature & Parks"
#         }
#       ]
#     },
#     {
#       "name": "Shankaracharya Hill",
#       "num_reviews": "2147",
#       "rating": "4.5",
#       "ranking_position": "1",
#       "neighborhood_info": null,
#       "description": "",
#       "subcategory": [
#         {
#           "key": "47",
#           "name": "Sights & Landmarks"
#         }
#       ]
#     },
#     {
#       "name": "Nishat Garden",
#       "num_reviews": "1332",
#       "rating": "4.2",
#       "ranking_position": "5",
#       "neighborhood_info": null,
#       "description": "",
#       "subcategory": [
#         {
#           "key": "57",
#           "name": "Nature & Parks"
#         }
#       ]
#     },
#     {
#       "name": "Nigeen Lake",
#       "num_reviews": "1120",
#       "rating": "4.4",
#       "ranking_position": "3",
#       "neighborhood_info": null,
#       "description": "",
#       "subcategory": [
#         {
#           "key": "57",
#           "name": "Nature & Parks"
#         }
#       ]
#     },
#     {
#       "name": "Yousmarg",
#       "num_reviews": "249",
#       "rating": "4.4",
#       "ranking_position": "15",
#       "neighborhood_info": null,
#       "description": "",
#       "subcategory": [
#         {
#           "key": "47",
#           "name": "Sights & Landmarks"
#         },
#         {
#           "key": "57",
#           "name": "Nature & Parks"
#         },
#         {
#           "key": "61",
#           "name": "Outdoor Activities"
#         }
#       ]
#     },
#     {
#       "name": "Badamwari Garden",
#       "num_reviews": "157",
#       "rating": "4.5",
#       "ranking_position": "16",
#       "neighborhood_info": null,
#       "description": "",
#       "subcategory": [
#         {
#           "key": "57",
#           "name": "Nature & Parks"
#         }
#       ]
#     },
#     {
#       "name": "Mughal Gardens",
#       "num_reviews": "788",
#       "rating": "4.2",
#       "ranking_position": "10",
#       "neighborhood_info": null,
#       "description": "",
#       "subcategory": [
#         {
#           "key": "57",
#           "name": "Nature & Parks"
#         }
#       ]
#     },
#     {
#       "name": "Shalimar Bagh",
#       "num_reviews": "778",
#       "rating": "4.2",
#       "ranking_position": "9",
#       "neighborhood_info": null,
#       "description": "",
#       "subcategory": [
#         {
#           "key": "57",
#           "name": "Nature & Parks"
#         }
#       ]
#     }
#   ],
#   "hotels": {
#     "bayesian_review_score": [
#       {
#         "name": "John's Homestay",
#         "price": 55.1
#       },
#       {
#         "name": "Ikraam Inn Bed & Breakfast",
#         "price": 100.36
#       },
#       {
#         "name": "Movie land group of house boats",
#         "price": 125.29
#       }
#     ],
#     "popularity": [
#       {
#         "name": "Houseboat Zaindari Palace",
#         "price": 326.2
#       },
#       {
#         "name": "Dilnaaz group of houseboats",
#         "price": 73.47
#       },
#       {
#         "name": "Amina Group Of Houseboats",
#         "price": 174.93
#       }
#     ],
#     "price": [
#       {
#         "name": "LalaApartment",
#         "price": 13.07
#       },
#       {
#         "name": "Young Gulshan Apartment",
#         "price": 17.19
#       },
#       {
#         "name": "Shaheen Luxuries",
#         "price": 17.71
#       }
#     ]
#   },
#   "flights": [
#     {
#       "to": "Leh",
#       "date": "2025-07-14",
#       "flights": [
#         {
#           "type": "FASTEST",
#           "price_usd": 1301,
#           "departure_time": "2025-07-14T08:15:00",
#           "arrival_time": "2025-07-14T12:25:00"
#         },
#         {
#           "type": "BEST",
#           "price_usd": 681,
#           "departure_time": "2025-07-14T07:35:00",
#           "arrival_time": "2025-07-14T12:25:00"
#         }
#       ],
#       "note": null
#     }
#   ],
#   "arrival_date": "2025-07-12",
#   "departure_date": "2025-07-14",
#   "airport": "SXR",
#   "travellers": 4
# }

# %%
import pandas as pd
from IPython.display import display

# Flatten into a DataFrame (one row per city)
df = pd.json_normalize(final_list, sep="_")
display(df)

# Save JSON
out_path = "combined_data_hotel_attraction_flight_Apr_19th.json"
with open(out_path, "w") as f:
    json.dump(final_list, f, indent=2)

print("\u2705 Saved combined results to", out_path)
# Out:
#        city                                        attractions  \
# 0  Srinagar  [{'name': 'Dal Lake', 'num_reviews': '4329', '...
# 1       Leh  [{'name': 'Coca-Cola Park', 'num_reviews': '64...
# 2    Shimla  [{'name': 'Jakhu Hanuman Temple', 'num_reviews...
#
#                                              flights arrival_date  \
# 0  [{'to': 'Leh', 'date': '2025-07-14', 'flights'...   2025-07-12
# 1  [{'to': 'Shimla', 'date': '2025-07-16', 'fligh...   2025-07-14
# 2                                                 []   2025-07-16
#
#   departure_date airport  travellers  \
# 0     2025-07-14     SXR           4
# 1     2025-07-16     IXL           4
# 2     2025-07-19     SLV           4
#
#                         hotels_bayesian_review_score  \
# 0  [{'name': 'John's Homestay', 'price': 55.1}, {...
# 1  [{'name': 'Hyatt Place Salt Lake City/Lehi', '...
# 2  [{'name': 'Wildflower Hall, An Oberoi Resort, ...
#
#                                    hotels_popularity  \
# 0  [{'name': 'Houseboat Zaindari Palace', 'price'...
# 1  [{'name': 'Hyatt Place Salt Lake City/Lehi', '...
# 2  [{'name': 'Victory Hotel and Restaurant by GS ...
#
#                                         hotels_price
# 0  [{'name': 'LalaApartment', 'price': 13.07}, {'...
# 1  [{'name': 'Motel 6 Lehi, UT - Thanksgiving Poi...
# 2  [{'name': 'Staynest Mashobra with balcony', 'p...
# ✅ Saved combined results to combined_data_hotel_attraction_flight_Apr_19th.json
